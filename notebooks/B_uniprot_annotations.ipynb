# %% [markdown]
# # Yarrowia Annotions from Uniprot

# %% [markdown]
# ### Load imports

# %%
import pandas as pd

# %% [markdown]
# ### Load uniprot data

# %%
# load data/uniprot_annotations.tsv
uniprot_data = pd.read_csv('../data/uniprot_annotations.tsv', sep='\t')
uniprot_data.head()
# Out:
#     Entry         Gene Names  \
# 0  P09230  XPR2 YALI0F31889g
# 1  P34229  FAS1 YALI0B15059g
# 2  Q6C093  UBC2 YALI0F26697g
# 3  Q6C1X5  ARO1 YALI0F12639g
# 4  Q6C2F5  ATG9 YALI0F08349g
#
#                   Gene Ontology (molecular function)
# 0    serine-type endopeptidase activity [GO:0004252]
# 1  (3R)-hydroxymyristoyl-[acyl-carrier-protein] d...
# 2  ATP binding [GO:0005524]; proteasome binding [...
# 3  3-dehydroquinate dehydratase activity [GO:0003...
# 4      phospholipid scramblase activity [GO:0017128]

# %% [markdown]
# ### Fix gene names so that they match the KEGG format

# %%
# loop over the rows of uniprot_data
for _, row in uniprot_data.iterrows():
    # get the gene name
    gene_name = row['Gene Names']

    # split the gene name by spaces
    gene_name_split = gene_name.split(' ')

    # only keep the word that has 'YALI0' in it
    YALI0_gene_name = ''
    for word in gene_name_split:
        if 'YALI0' in word:
            YALI0_gene_name = word

    # remove the underscore character if it exists
    # if '_' in YALI0_gene_name:
    YALI0_gene_name = YALI0_gene_name.replace('_', '')
    
    # update the gene name column with the new gene name
    uniprot_data.loc[_, 'Gene Names'] = YALI0_gene_name

uniprot_data.head(50)
# Out:
#      Entry    Gene Names                 Gene Ontology (molecular function)
# 0   P09230  YALI0F31889g    serine-type endopeptidase activity [GO:0004252]
# 1   P34229  YALI0B15059g  (3R)-hydroxymyristoyl-[acyl-carrier-protein] d...
# 2   Q6C093  YALI0F26697g  ATP binding [GO:0005524]; proteasome binding [...
# 3   Q6C1X5  YALI0F12639g  3-dehydroquinate dehydratase activity [GO:0003...
# 4   Q6C2F5  YALI0F08349g      phospholipid scramblase activity [GO:0017128]
# 5   Q6C354  YALI0F02497g  2 iron, 2 sulfur cluster binding [GO:0051537];...
# 6   Q6C4M9  YALI0E25135g  ATP binding [GO:0005524]; MAP kinase activity ...
# 7   Q6C6R8  YALI0E06831g  peroxisome matrix targeting signal-1 binding [...
# 8   Q6C710  YALI0E04675g  histone H3K4 acetyltransferase activity [GO:00...
# 9   Q6C793  YALI0E02684g  2-methylcitrate synthase activity [GO:0050440]...
# 10  Q6C7C0  YALI0E02046g  actin filament binding [GO:0051015]; Arp2/3 co...
# 11  Q6C7R4  YALI0D26015g  ATP binding [GO:0005524]; centromeric DNA bind...
# 12  Q6C7U0  YALI0D25388g  ATP binding [GO:0005524]; protein serine kinas...
# 13  Q6C7U8  YALI0D25190g  ATP binding [GO:0005524]; cyclin-dependent pro...
# 14  Q6CCB0  YALI0C10967g  ATP binding [GO:0005524]; cyclin-dependent pro...
# 15  Q6CF29  YALI0B10758g  ATP binding [GO:0005524]; cyclin binding [GO:0...
# 16  Q6CFS5  YALI0B04268g  ATP binding [GO:0005524]; identical protein bi...
# 17  Q6CFT7  YALI0B03982g  ADP binding [GO:0043531]; ATP binding [GO:0005...
# 18  Q6CHJ9  YALI0A08077g  myosin phosphatase activity [GO:0017018]; prot...
# 19  B5FVG3  YALI0E32164g  proton transmembrane transporter activity [GO:...
# 20  F2Z699  YALI0F25135g  NADH dehydrogenase (quinone) activity [GO:0050...
# 21  F2Z6C9  YALI0D04422g  flavin adenine dinucleotide binding [GO:005066...
# 22  O43108  YALI0E09471g  ATP binding [GO:0005524]; ATP hydrolysis activ...
# 23  O74932  YALI0E14685g  alpha,alpha-trehalose-phosphate synthase (UDP-...
# 24  O74934  YALI0E32835g  acyl-CoA oxidase activity [GO:0003997]; FAD bi...
# 25  O74935  YALI0F10857g  acyl-CoA oxidase activity [GO:0003997]; FAD bi...
# 26  O74936  YALI0D24750g  acyl-CoA oxidase activity [GO:0003997]; FAD bi...
# 27  P18120  YALI0C00407g  3-isopropylmalate dehydrogenase activity [GO:0...
# 28  P41555  YALI0C16885g  isocitrate lyase activity [GO:0004451]; metal ...
# 29  P59680  YALI0D16357g  6-phosphofructokinase activity [GO:0003872]; A...
# 30  P80547  YALI0E01298g                         lipid binding [GO:0008289]
# 31  Q05493  YALI0E18568g  acetyl-CoA C-acyltransferase activity [GO:0003...
# 32  Q36257                proton transmembrane transporter activity [GO:...
# 33  Q36258                proton transmembrane transporter activity [GO:...
# 34  Q37695                lipid binding [GO:0008289]; proton transmembra...
# 35  Q6BZP5  YALI0F31999g  isocitrate lyase activity [GO:0004451]; methyl...
# 36  Q6C079  YALI0F27093g  ATP binding [GO:0005524]; calcium-dependent pr...
# 37  Q6C0B5  YALI0F26169g  ATP binding [GO:0005524]; ATP hydrolysis activ...
# 38  Q6C0T3  YALI0F21945g  ATP binding [GO:0005524]; ATP hydrolysis activ...
# 39  Q6C0Z6  YALI0F20504g  cytochrome-c peroxidase activity [GO:0004130];...
# 40  Q6C105  YALI0F20306g  proton-transporting ATP synthase activity, rot...
# 41  Q6C116  YALI0F20042g  5'-3' exonuclease activity [GO:0008409]; 5'-fl...
# 42  Q6C195  YALI0F18194g  myosin phosphatase activity [GO:0017018]; prot...
# 43  Q6C1K4  YALI0F15477g  ATP binding [GO:0005524]; ATP-dependent activi...
# 44  Q6C292  YALI0F09746g  ATP binding [GO:0005524]; calcium-dependent pr...
# 45  Q6C2A3  YALI0F09471g  ATP binding [GO:0005524]; hydrolase activity [...
# 46  Q6C2N4  YALI0F06402g  ATP hydrolysis activity [GO:0016887]; chromati...
# 47  Q6C2N7  YALI0F06358g  phospholipase activity [GO:0004620]; triglycer...
# 48  Q6C2V4  YALI0F04818g  3'-5' DNA/RNA helicase activity [GO:0033679]; ...
# 49  Q6C2W1  YALI0F04664g  ATP binding [GO:0005524]; chromatin binding [G...

# %% [markdown]
# ### Remove rows with blank 'Gene Names'	or 'Gene Ontology (molecular function)'

# %%
# get the total number of genes in the uniprot dataset
total_genes = len(uniprot_data)

# remove rows with blank 'Gene Names'	or 'Gene Ontology (molecular function)'
uniprot_data = uniprot_data[uniprot_data['Gene Names'].notna()]
uniprot_data = uniprot_data[uniprot_data['Gene Ontology (molecular function)'].notna()]

# get the number of genes with annotations
uniprot_annotated_genes = len(uniprot_data)

print(f'Of the {total_genes} genes in the uniprot dataset, {uniprot_annotated_genes} have annotations')

# display the uniprot data
uniprot_data
# Out:
# Of the 6454 genes in the uniprot dataset, 4057 have annotations
#        Entry    Gene Names                 Gene Ontology (molecular function)
# 0     P09230  YALI0F31889g    serine-type endopeptidase activity [GO:0004252]
# 1     P34229  YALI0B15059g  (3R)-hydroxymyristoyl-[acyl-carrier-protein] d...
# 2     Q6C093  YALI0F26697g  ATP binding [GO:0005524]; proteasome binding [...
# 3     Q6C1X5  YALI0F12639g  3-dehydroquinate dehydratase activity [GO:0003...
# 4     Q6C2F5  YALI0F08349g      phospholipid scramblase activity [GO:0017128]
# ...      ...           ...                                                ...
# 6448  W0TYP4  YALI0B03080g                    catalytic activity [GO:0003824]
# 6449  W0TYP9  YALI0B09977g  protein-macromolecule adaptor activity [GO:003...
# 6450  W0TYQ0  YALI0B15722g  ATP binding [GO:0005524]; phosphorelay sensor ...
# 6451  W0TYQ3  YALI0A01602g  damaged DNA binding [GO:0003684]; single-stran...
# 6452  W0TYQ4  YALI0A19404g  helicase activity [GO:0004386]; RNA binding [G...
#
# [4057 rows x 3 columns]

# %% [markdown]
# ### Make a function to convert YALI0 gene ids to uniprot annotations

# %%
def yali0_to_uniprot_annotation(yali0_id):
    # get the uniprot annotations for the gene
    uniprot_annotations = uniprot_data[uniprot_data['Gene Names'].str.contains(yali0_id)]
    
    # if there are no annotations, return None
    if len(uniprot_annotations) == 0:
        return 'unknown function'
    
    # if there are annotations, return the first one
    else:
        return uniprot_annotations.iloc[0]['Gene Ontology (molecular function)']
    
yali0_to_uniprot_annotation('YALI0A00110g')
# Out:
# 'oligopeptide transmembrane transporter activity [GO:0035673]'

# %% [markdown]
# ### Load yarrowia KEGG annotations

# %%
# load results/yarrowia_annotations.csv
yarrowia_annotations = pd.read_csv('../results/yarrowia_annotations_kegg.csv')
yarrowia_annotations.head()
# Out:
#                JGI ID  JGI start  JGI end  NCBI start  NCBI end  \
# 0  jgi.p|Yarli1|64471       2659     5277        2659      5277
# 1  jgi.p|Yarli1|64472       7045     8880        7045      8880
# 2  jgi.p|Yarli1|64473      11559    12653       11559     12653
# 3  jgi.p|Yarli1|64474      15861    18419       15861     18419
# 4  jgi.p|Yarli1|64475      20087    20857       20087     20857
#
#          NCBI ID       Column1          NCBI  \
# 0  YALI0_A00110g  YALI0A00110g  YALI0A00110g
# 1  YALI0_A00132g  YALI0A00132g  YALI0A00132g
# 2  YALI0_A00154g  YALI0A00154g  YALI0A00154g
# 3  YALI0_A00176g  YALI0A00176g  YALI0A00176g
# 4  YALI0_A00198g  YALI0A00198g  YALI0A00198g
#
#                             kegg_annotation
# 0                          unknown function
# 1  K03283 heat shock 70kDa protein 1/2/6/8
# 2                          unknown function
# 3                          unknown function
# 4                          unknown function

# %% [markdown]
# ### Add Uniprot annotations as a column to the KEGG annotations

# %%
# add uniprot annotations as a column to the KEGG annotations
uniprot_annotation_list = []

# iterate over the rows of the KEGG dataframe
for _, row in yarrowia_annotations.iterrows():
    # get the YALI0 gene name
    YALI0_gene_name = row['NCBI']

    # get the uniprot annotation
    uniprot_annotation = yali0_to_uniprot_annotation(YALI0_gene_name)

    # append to the list
    uniprot_annotation_list.append(uniprot_annotation)

# add the list as a column to the dataframe
yarrowia_annotations['uniprot_annotation'] = uniprot_annotation_list

# display the dataframe
yarrowia_annotations
# Out:
#                   JGI ID  JGI start  JGI end  NCBI start  NCBI end  \
# 0     jgi.p|Yarli1|64471       2659     5277        2659      5277
# 1     jgi.p|Yarli1|64472       7045     8880        7045      8880
# 2     jgi.p|Yarli1|64473      11559    12653       11559     12653
# 3     jgi.p|Yarli1|64474      15861    18419       15861     18419
# 4     jgi.p|Yarli1|64475      20087    20857       20087     20857
# ...                  ...        ...      ...         ...       ...
# 6442  jgi.p|Yarli1|70913    3967026  3973618     3967026   3973618
# 6443  jgi.p|Yarli1|70914    3979479  3981272     3979479   3981272
# 6444  jgi.p|Yarli1|70915    3984293  3985643     3984293   3985643
# 6445  jgi.p|Yarli1|70916    3985832  3989074     3985832   3989074
# 6446  jgi.p|Yarli1|70917    3989662  3992157     3989662   3992157
#
#             NCBI ID       Column1          NCBI  \
# 0     YALI0_A00110g  YALI0A00110g  YALI0A00110g
# 1     YALI0_A00132g  YALI0A00132g  YALI0A00132g
# 2     YALI0_A00154g  YALI0A00154g  YALI0A00154g
# 3     YALI0_A00176g  YALI0A00176g  YALI0A00176g
# 4     YALI0_A00198g  YALI0A00198g  YALI0A00198g
# ...             ...           ...           ...
# 6442  YALI0_F32043g  YALI0F32043g  YALI0F32043g
# 6443  YALI0_F32065g  YALI0F32065g  YALI0F32065g
# 6444  YALI0_F32131g  YALI0F32131g  YALI0F32131g
# 6445  YALI0_F32153g  YALI0F32153g  YALI0F32153g
# 6446  YALI0_F32175g  YALI0F32175g  YALI0F32175g
#
#                                         kegg_annotation  \
# 0                                      unknown function
# 1              K03283 heat shock 70kDa protein 1/2/6/8
# 2                                      unknown function
# 3                                      unknown function
# 4                                      unknown function
# ...                                                 ...
# 6442             K19844 GTPase-activating protein BEM2
# 6443                                   unknown function
# 6444                                   unknown function
# 6445  K23358 transcription initiation factor TFIID s...
# 6446                                   unknown function
#
#                                      uniprot_annotation
# 0     oligopeptide transmembrane transporter activit...
# 1     ATP binding [GO:0005524]; ATP hydrolysis activ...
# 2                                      unknown function
# 3                                      unknown function
# 4                                      unknown function
# ...                                                 ...
# 6442  GTPase activator activity [GO:0005096]; guanyl...
# 6443                                   unknown function
# 6444          triglyceride lipase activity [GO:0004806]
# 6445  histone acetyltransferase activity [GO:0004402...
# 6446                                   unknown function
#
# [6447 rows x 10 columns]

# %%
# save the yarrowia_annotations dataframe to a xlsx file
yarrowia_annotations.to_excel('../results/yarrowia_annotations_kegg_uniprot.xlsx', index=False)

# %% [markdown]
# ### Check annotation completeness

# %%
both_annotated_list = []
only_kegg_list = []
only_uniprot_list = []
neither_annotated_list = []

temp = []

# loop over rows in the dataframe
for _, row in yarrowia_annotations.iterrows():
    has_kegg_annotation = True
    has_uniprot_annotation = True

    # get kegg and uniprot annotations
    kegg_annotation = row['kegg_annotation']
    uniprot_annotation = row['uniprot_annotation']

    # update has_kegg_annotation
    if kegg_annotation == 'gene not in KEGG' or kegg_annotation == 'unknown function':
        has_kegg_annotation = False

    # update has_uniprot_annotation
    if uniprot_annotation == 'unknown function':
        has_uniprot_annotation = False

    # update lists
    if has_kegg_annotation and has_uniprot_annotation:
        both_annotated_list.append(row)
    elif has_kegg_annotation and not has_uniprot_annotation:
        only_kegg_list.append(row)
    elif not has_kegg_annotation and has_uniprot_annotation:
        only_uniprot_list.append(row)
    else:
        neither_annotated_list.append(row)
        
# print total number of genes
total_genes = len(both_annotated_list) + len(only_kegg_list) + len(only_uniprot_list) + len(neither_annotated_list)
print(f'total number of genes: {total_genes}')

# print lengths of lists
print(f'both_annotated_list: {len(both_annotated_list)} ({100 * len(both_annotated_list) / total_genes:.1f}%)')
print(f'only_kegg_list: {len(only_kegg_list)} ({100 * len(only_kegg_list) / total_genes:.1f}%)')
print(f'only_uniprot_list: {len(only_uniprot_list)} ({100 * len(only_uniprot_list) / total_genes:.1f}%)')
print(f'neither_annotated_list: {len(neither_annotated_list)} ({100 * len(neither_annotated_list) / total_genes:.1f}%)')
# Out:
# total number of genes: 6447
# both_annotated_list: 2882 (44.7%)
# only_kegg_list: 634 (9.8%)
# only_uniprot_list: 1148 (17.8%)
# neither_annotated_list: 1783 (27.7%)
